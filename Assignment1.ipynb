# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(0,100, size=(4,4)), columns=list('ABCD'))

# %%
df
# Out:
#     A   B   C   D
# 0  10  70  78  52
# 1  40   9  34  23
# 2  92  58   6  10
# 3  56  48  82   6

# %%
df2 = df.rename(columns={"A":"Random Value 1","B":"Random Value 2","C":"Random Value 3","D":"Random Value 4"})
print(df2)
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0              10              70              78              52
# 1              40               9              34              23
# 2              92              58               6              10
# 3              56              48              82               6

# %%
stats = df2.describe(include = "all")
print(stats)
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000         4.00000
# mean        49.500000       46.250000       50.000000        22.75000
# std         34.151623       26.411803       36.514837        20.80665
# min         10.000000        9.000000        6.000000         6.00000
# 25%         32.500000       38.250000       27.000000         9.00000
# 50%         48.000000       53.000000       56.000000        16.50000
# 75%         65.000000       61.000000       79.000000        30.25000
# max         92.000000       70.000000       82.000000        52.00000

# %%
df2.isnull().any()
# Out:
# Random Value 1    False
# Random Value 2    False
# Random Value 3    False
# Random Value 4    False
# dtype: bool

# %%
a = df2.dtypes
print(a)
# Out:
# Random Value 1    int64
# Random Value 2    int64
# Random Value 3    int64
# Random Value 4    int64
# dtype: object

# %%
df2.loc[:,["Random Value 2","Random Value 3"]]
# Out:
#    Random Value 2  Random Value 3
# 0              70              78
# 1               9              34
# 2              58               6
# 3              48              82

# %%
df2.iloc[:,[1,2]]
# Out:
#    Random Value 2  Random Value 3
# 0              70              78
# 1               9              34
# 2              58               6
# 3              48              82
